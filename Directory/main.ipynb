# %%
#PySteak Homework
#Import Libraries

import csv
from pathlib import Path

# %%
#Load the menu and sales info into list variables, split off headers
# Initializing list objects for the CSVs
# Return the menu and sales 

def load_menu_and_sales_csv():
    #Setting file paths for menu_data and sales_Data
    menu_filepath = Path('Resources/menu_data.csv')
    sales_filepath = Path('Resources/sales_data.csv')
    menu_header = []
    menu = []
    sales_header = []
    sales = []
    
    #Reading the menu_csv into list, splitting off header
    with open(menu_filepath, 'r') as file:
        menu_reader = csv.reader(file, delimiter=',')
        menu_header = next(menu_reader)
        for line in menu_reader:
            menu.append(line)
            
    #Reading the sales_csv into list, splitting off header
    with open(sales_filepath, 'r') as file:
        sales_reader = csv.reader(file, delimiter=',')
        sales_header = next(sales_reader)
        for line in sales_reader:
            sales.append(line)
            
    return menu, sales

# %%
#Create a dictionary, with key as each menu item, and value as the report_template dictionary
# Return this dict
def create_total_sales_dict(menu):
    sales_report = {}
    #Initialize the report dict template 
    report_template = {
    '01-count': 0, 
    '02-revenue': 0, 
    '03-cogs': 0, 
    '04-profit': 0, 
    }
    for row in menu:
        item = row[0]
        if item not in sales_report.keys():
            sales_report[item] = dict(report_template)
    
    # Return sales_report dict, fully populated
    return sales_report

# %%
#Populate & tabulate quantity from sales data into total sales_report dicts (total info) and date_sales_tracker dicts (daily)
# Return data_tracker_month and date_sales_tracker
def create_daily_sales_dict(sales, sales_report):
    date_tracker_month = []
    date_sales_tracker = {}
    report_template = {
    '01-count': 0, 
    '02-revenue': 0, 
    '03-cogs': 0, 
    '04-profit': 0, 
    }
    
    for row in sales:
        
        # Establish and populate date_tracker_month
        date = row[1].replace("-", "")
        date_month = int(date[-4:] + date[:2])
        if date_month not in date_tracker_month:
            date_tracker_month.append(date_month)
        
        # Convert data from sales records into usable local variables
        date_daily = row[1]
        sales_item = row[4]
        quant = int(row[3])
    
        # Populate the date_sales_tracker with unique days, exclude duplicates
        if date_daily not in date_sales_tracker.keys():
            date_sales_tracker[date_daily] = {}
    
        # Populate the particular days in date_sales_tracker with unique menu item sales, exclude duplicates
        if sales_item not in date_sales_tracker[date_daily].keys():
            placeholder_dict = {}
            placeholder_dict[sales_item] = dict(report_template)
            date_sales_tracker[date_daily].update(placeholder_dict)

        # Populate first the daily sales quantity total, and then the overall sales quantity total
        date_sales_tracker[date_daily][sales_item]["01-count"] += quant
        if sales_item in sales_report.keys():
            sales_report[sales_item]["01-count"] += quant

    return date_tracker_month, date_sales_tracker

# %%
# Fill in revenue, cogs, profit using sales and relevant info from menu
# Dictionaries are not returned back b/c they are mutable objects and can be modified if passed into function

def populate_revenue_cogs_profit(menu, sales_report, date_sales_tracker):
    for row in menu:

        # Convert data from menu into usable variables
        item = row[0]
        price = float(row[3])
        cost = float(row[4])

        # Calculate 02, 03, and 04 for the overall sales tracker
        if item in sales_report.keys():
            quantity = sales_report[item]["01-count"]
            sales_report[item]["02-revenue"] += (quantity * price)
            sales_report[item]["03-cogs"] += (quantity * cost)
            sales_report[item]["04-profit"] += (quantity * (price - cost))

        # Calculate 02, 03, and 04 for the individual daily sales using nested for loop to loop through 
        # nested dict structure   date_sales_tracked = { 
        #                           "each date of sales" : { 
        #                               "each unique item sold on that date" : { 
        #                                    "01": ,"02": ,"03" : ,"04": 
        for dates in date_sales_tracker:
            if item in date_sales_tracker[dates].keys():
                quantity = date_sales_tracker[dates][item]["01-count"]
                date_sales_tracker[dates][item]["02-revenue"] += (quantity * price)
                date_sales_tracker[dates][item]["03-cogs"] += (quantity * cost)
                date_sales_tracker[dates][item]["04-profit"] += (quantity * (price - cost))

# %%
# Make a list of all 0 quantity items in the dict sales_report, then remove them from the sales_report
def clean_up_sales_report(sales_report):
    pop_list = []
    for k in sales_report:
        item = k
        if item in sales_report.keys():
            if sales_report[item]["01-count"] == 0:
                pop_list.append(item)
    for k in pop_list:
        sales_report.pop(k)

# %%
# Prepare and publish overall sales output CSV
def prepare_and_publish_total_sales_output_csv(sales_report):
    report_header = ["Item", "Quantity", "Revenue", "COGS", "Profit"]
    total_sales_report_output = Path("total_sales_report.csv")
    with open(total_sales_report_output, "w") as total_sales_report_csv_file:
        csvwriter = csv.writer(total_sales_report_csv_file, delimiter=",")
        csvwriter.writerow(report_header)
        for item in sales_report:
            csvwriter.writerow(
                [
                    item,
                    sales_report[item]["01-count"],
                    sales_report[item]["02-revenue"],
                    sales_report[item]["03-cogs"],
                    sales_report[item]["04-profit"]
                ]
            )

# %%
#Print the total months
def print_total_months(date_tracker_month):
    print(f"The number of months in the dataset is: {len(date_tracker_month)}")

# %%
#Calculate and print total net profit for each item, and most profitable item
def calculate_and_print_profitability_report(sales_report):
    most_profitable_overall_item = ''
    profit_amount = 0
    for k in sales_report.keys():
        item = k
        profit = sales_report[item]["04-profit"]
        if profit > profit_amount:
            most_profitable_overall_item = k
            profit_amount = profit
        print(f"Item: {k} ... Total Net Profit: ${profit}")
    print()
    print(f"The {most_profitable_overall_item} is the most profitable at ${profit_amount}")
    print()

# %%
#Calculate  the most profitable item for each date, and amount sold.  Same for most expensive item
#Total_daily_report_list used for printing daily sales report below
# Returns total_daily_report_list

def total_daily_report_preparation(date_sales_tracker):
    #Initialize list, to be used to hold each individual day's highest profit and highest cost items
    total_daily_report_list =[]
    for dates in date_sales_tracker:
        max_profit_item = ''
        max_profit_item_sales = 0
        max_profit_item_profit = 0
        max_cost_item_name = ''
        max_cost_item_cost = 0
        for a in date_sales_tracker[dates].keys():
            if date_sales_tracker[dates][a]["04-profit"] > max_profit_item_profit:
                max_profit_item_profit = date_sales_tracker[dates][a]["04-profit"]
                max_profit_item_sales = date_sales_tracker[dates][a]["01-count"]
                max_profit_item = a
            if date_sales_tracker[dates][a]["03-cogs"] > max_cost_item_cost:
                max_cost_item_cost = date_sales_tracker[dates][a]["03-cogs"]
                max_cost_item_name = a
        final_daily_report_numbers = [dates, max_profit_item, max_profit_item_profit, max_profit_item_sales, max_cost_item_name, max_cost_item_cost] 
        total_daily_report_list.append(final_daily_report_numbers)
    return total_daily_report_list

# %%
# Prepare and publish total_daily_report as an output CSV
def write_and_publish_daily_report_csv(total_daily_report_list):
    max_min_daily_report_header = ["Date", "Max Profit Item", "Profit of MPI", "Sales of MPI", "Max Cost Item", "Sales of MCI"]
    max_min_daily_sales_report_output = Path("max_min_daily_sales_report.csv")
    with open(max_min_daily_sales_report_output, "w", newline='') as max_min_daily_sales_report_csv_file:
        csvwriter = csv.writer(max_min_daily_sales_report_csv_file, delimiter=",")
        csvwriter.writerow(max_min_daily_report_header)
        csvwriter.writerows(total_daily_report_list)

# %%
# Print out the daily report list
def print_total_daily_report_list(total_daily_report_list):
    row_counter= 0
    for i in total_daily_report_list:
        print(f"{total_daily_report_list[row_counter][0]}'s {total_daily_report_list[row_counter][1]} = most profitable. Sold {total_daily_report_list[row_counter][3]} for ${total_daily_report_list[row_counter][2]}")
        print(f"{total_daily_report_list[row_counter][0]}'s {total_daily_report_list[row_counter][4]} = most expensive. A total cost of ${total_daily_report_list[row_counter][5]}")
        print()
        row_counter += 1

# %%
# Call functions to run the program
def main():
    menu, sales = load_menu_and_sales_csv()
    sales_report = create_total_sales_dict(menu)
    date_tracker_month, date_sales_tracker = create_daily_sales_dict(sales, sales_report)
    populate_revenue_cogs_profit(menu, sales_report, date_sales_tracker)
    clean_up_sales_report(sales_report)
    prepare_and_publish_total_sales_output_csv(sales_report)
    print_total_months(date_tracker_month)
    calculate_and_print_profitability_report(sales_report)
    total_daily_report_list = total_daily_report_preparation(date_sales_tracker)
    write_and_publish_daily_report_csv(total_daily_report_list)
    print_total_daily_report_list(total_daily_report_list)
    
main()
# Out:
# The number of months in the dataset is: 24
# Item: nagomi shoyu ... Total Net Profit: $54792.0
# Item: shio ramen ... Total Net Profit: $55080.0
# Item: spicy miso ramen ... Total Net Profit: $64666.0
# Item: vegetarian spicy miso ... Total Net Profit: $64512.0
# Item: miso crab ramen ... Total Net Profit: $53340.0
# Item: soft-shell miso crab ramen ... Total Net Profit: $63910.0
# Item: tori paitan ramen ... Total Net Profit: $64092.0
# Item: tonkotsu ramen ... Total Net Profit: $65016.0
# Item: burnt garlic tonkotsu ramen ... Total Net Profit: $72560.0
# Item: vegetarian curry + king trumpet mushroom ramen ... Total Net Profit: $52944.0
# Item: truffle butter ramen ... Total Net Profit: $62874.0
#
# The burnt garlic tonkotsu ramen is the most profitable at $72560.0
#
# 01-01-2017's vegetarian spicy miso = most profitable. Sold 38 for $266.0
# 01-01-2017's truffle butter ramen = most expensive. A total cost of $252.0
#
# 01-02-2017's soft-shell miso crab ramen = most profitable. Sold 4 for $28.0
# 01-02-2017's soft-shell miso crab ramen = most expensive. A total cost of $28.0
#
# 01-03-2017's burnt garlic tonkotsu ramen = most profitable. Sold 34 for $272.0
# 01-03-2017's burnt garlic tonkotsu ramen = most expensive. A total cost of $204.0
#
# 01-04-2017's spicy miso ramen = most profitable. Sold 32 for $224.0
# 01-04-2017's spicy miso ramen = most expensive. A total cost of $160.0
#
# 01-05-2017's soft-shell miso crab ramen = most profitable. Sold 36 for $252.0
# 01-05-2017's soft-shell miso crab ramen = most expensive. A total cost of $252.0
#
# 01-06-2017's spicy miso ramen = most profitable. Sold 40 for $280.0
# 01-06-2017's shio ramen = most expensive. A total cost of $200.0
#
# 01-07-2017's nagomi shoyu = most profitable. Sold 6 for $36.0
# 01-07-2017's nagomi shoyu = most expensive. A total cost of $30.0
#
# 01-08-2017's vegetarian spicy miso = most profitable. Sold 24 for $168.0
# 01-08-2017's vegetarian spicy miso = most expensive. A total cost of $120.0
#
# 01-09-2017's miso crab ramen = most profitable. Sold 20 for $120.0
# 01-09-2017's miso crab ramen = most expensive. A total cost of $120.0
#
# 01-10-2017's vegetarian spicy miso = most profitable. Sold 14 for $98.0
# 01-10-2017's miso crab ramen = most expensive. A total cost of $84.0
#
# 01-11-2017's vegetarian spicy miso = most profitable. Sold 30 for $210.0
# 01-11-2017's miso crab ramen = most expensive. A total cost of $168.0
#
# 01-12-2017's soft-shell miso crab ramen = most profitable. Sold 36 for $252.0
# 01-12-2017's soft-shell miso crab ramen = most expensive. A total cost of $252.0
#
# 01-13-2017's vegetarian spicy miso = most profitable. Sold 14 for $98.0
# 01-13-2017's burnt garlic tonkotsu ramen = most expensive. A total cost of $72.0
#
# 01-14-2017's vegetarian spicy miso = most profitable. Sold 38 for $266.0
# 01-14-2017's vegetarian spicy miso = most expensive. A total cost of $190.0
#
# 01-15-2017's tonkotsu ramen = most profitable. Sold 24 for $168.0
# 01-15-2017's tonkotsu ramen = most expensive. A total cost of $144.0
#
# 01-16-2017's spicy miso ramen = most profitable. Sold 24 for $168.0
# 01-16-2017's vegetarian curry + king trumpet mushroom ramen = most expensive. A total cost of $182.0
#
# 01-17-2017's vegetarian spicy miso = most profitable. Sold 46 for $322.0
# 01-17-2017's vegetarian spicy miso = most expensive. A total cost of $230.0
#
# 01-18-2017's truffle butter ramen = most profitable. Sold 8 for $56.0
# 01-18-2017's truffle butter ramen = most expensive. A total cost of $56.0
#
# 01-19-2017's tonkotsu ramen = most profitable. Sold 8 for $56.0
# 01-19-2017's tonkotsu ramen = most expensive. A total cost of $48.0
#
# 01-20-2017's tonkotsu ramen = most profitable. Sold 22 for $154.0
# 01-20-2017's tonkotsu ramen = most expensive. A total cost of $132.0
#
# 01-21-2017's shio ramen = most profitable. Sold 16 for $96.0
# 01-21-2017's shio ramen = most expensive. A total cost of $80.0
#
# 01-22-2017's spicy miso ramen = most profitable. Sold 22 for $154.0
# 01-22-2017's spicy miso ramen = most expensive. A total cost of $110.0
#
# 01-23-2017's nagomi shoyu = most profitable. Sold 28 for $168.0
# 01-23-2017's nagomi shoyu = most expensive. A total cost of $140.0
#
# 01-24-2017's vegetarian curry + king trumpet mushroom ramen = most profitable. Sold 32 for $192.0
# 01-24-2017's vegetarian curry + king trumpet mushroom ramen = most expensive. A total cost of $224.0
#
# 01-25-2017's truffle butter ramen = most profitable. Sold 44 for $308.0
# 01-25-2017's truffle butter ramen = most expensive. A total cost of $308.0
#
# 01-26-2017's burnt garlic tonkotsu ramen = most profitable. Sold 12 for $96.0
# 01-26-2017's burnt garlic tonkotsu ramen = most expensive. A total cost of $72.0
#
# 01-27-2017's nagomi shoyu = most profitable. Sold 16 for $96.0
# 01-27-2017's nagomi shoyu = most expensive. A total cost of $80.0
#
# 01-28-2017's soft-shell miso crab ramen = most profitable. Sold 34 for $238.0
# 01-28-2017's soft-shell miso crab ramen = most expensive. A total cost of $238.0
#
# 01-29-2017's truffle butter ramen = most profitable. Sold 34 for $238.0
# 01-29-2017's truffle butter ramen = most expensive. A total cost of $238.0
#
# 01-30-2017's vegetarian spicy miso = most profitable. Sold 6 for $42.0
# 01-30-2017's tori paitan ramen = most expensive. A total cost of $36.0
#
# 01-31-2017's vegetarian spicy miso = most profitable. Sold 10 for $70.0
# 01-31-2017's vegetarian spicy miso = most expensive. A total cost of $50.0
#
# 02-01-2017's vegetarian spicy miso = most profitable. Sold 26 for $182.0
# 02-01-2017's soft-shell miso crab ramen = most expensive. A total cost of $168.0
#
# 02-02-2017's burnt garlic tonkotsu ramen = most profitable. Sold 10 for $80.0
# 02-02-2017's burnt garlic tonkotsu ramen = most expensive. A total cost of $60.0
#
# 02-03-2017's tori paitan ramen = most profitable. Sold 36 for $252.0
# 02-03-2017's vegetarian curry + king trumpet mushroom ramen = most expensive. A total cost of $238.0
#
# 02-04-2017's truffle butter ramen = most profitable. Sold 24 for $168.0
# 02-04-2017's truffle butter ramen = most expensive. A total cost of $168.0
#
# 02-05-2017's tori paitan ramen = most profitable. Sold 24 for $168.0
# 02-05-2017's miso crab ramen = most expensive. A total cost of $156.0
#
# 02-06-2017's spicy miso ramen = most profitable. Sold 12 for $84.0
# 02-06-2017's burnt garlic tonkotsu ramen = most expensive. A total cost of $60.0
#
# 02-07-2017's shio ramen = most profitable. Sold 52 for $312.0
# 02-07-2017's shio ramen = most expensive. A total cost of $260.0
#
# 02-08-2017's burnt garlic tonkotsu ramen = most profitable. Sold 14 for $112.0
# 02-08-2017's burnt garlic tonkotsu ramen = most expensive. A total cost of $84.0
#
# 02-09-2017's spicy miso ramen = most profitable. Sold 22 for $154.0
# 02-09-2017's truffle butter ramen = most expensive. A total cost of $140.0
#
# 02-10-2017's vegetarian spicy miso = most profitable. Sold 20 for $140.0
# 02-10-2017's soft-shell miso crab ramen = most expensive. A total cost of $140.0
#
# 02-11-2017's soft-shell miso crab ramen = most profitable. Sold 2 for $14.0
# 02-11-2017's soft-shell miso crab ramen = most expensive. A total cost of $14.0
#
# 02-13-2017's burnt garlic tonkotsu ramen = most profitable. Sold 32 for $256.0
# 02-13-2017's burnt garlic tonkotsu ramen = most expensive. A total cost of $192.0
#
# 02-14-2017's burnt garlic tonkotsu ramen = most profitable. Sold 16 for $128.0
# 02-14-2017's burnt garlic tonkotsu ramen = most expensive. A total cost of $96.0
#
# 02-15-2017's spicy miso ramen = most profitable. Sold 30 for $210.0
# 02-15-2017's spicy miso ramen = most expensive. A total cost of $150.0
#
# 02-16-2017's spicy miso ramen = most profitable. Sold 18 for $126.0
# 02-16-2017's spicy miso ramen = most expensive. A total cost of $90.0
#
# 02-17-2017's burnt garlic tonkotsu ramen = most profitable. Sold 26 for $208.0
# 02-17-2017's burnt garlic tonkotsu ramen = most expensive. A total cost of $156.0
#
# 02-18-2017's vegetarian spicy miso = most profitable. Sold 20 for $140.0
# 02-18-2017's soft-shell miso crab ramen = most expensive. A total cost of $126.0
#
# 02-19-2017's miso crab ramen = most profitable. Sold 44 for $264.0
# 02-19-2017's miso crab ramen = most expensive. A total cost of $264.0
#
# 02-20-2017's truffle butter ramen = most profitable. Sold 4 for $28.0
# 02-20-2017's truffle butter ramen = most expensive. A total cost of $28.0
#
# 02-21-2017's miso crab ramen = most profitable. Sold 4 for $24.0
# 02-21-2017's miso crab ramen = most expensive. A total cost of $24.0
#
# 02-22-2017's vegetarian spicy miso = most profitable. Sold 36 for $252.0
# 02-22-2017's vegetarian spicy miso = most expensive. A total cost of $180.0
#
# 02-23-2017's nagomi shoyu = most profitable. Sold 22 for $132.0
# 02-23-2017's vegetarian curry + king trumpet mushroom ramen = most expensive. A total cost of $140.0
#
# 02-24-2017's soft-shell miso crab ramen = most profitable. Sold 20 for $140.0
# 02-24-2017's soft-shell miso crab ramen = most expensive. A total cost of $140.0
#
# 02-25-2017's shio ramen = most profitable. Sold 14 for $84.0
# 02-25-2017's shio ramen = most expensive. A total cost of $70.0
#
# 02-26-2017's tori paitan ramen = most profitable. Sold 20 for $140.0
# 02-26-2017's tori paitan ramen = most expensive. A total cost of $120.0
#
# 02-27-2017's burnt garlic tonkotsu ramen = most profitable. Sold 4 for $32.0
# 02-27-2017's burnt garlic tonkotsu ramen = most expensive. A total cost of $24.0
#
# 02-28-2017's tonkotsu ramen = most profitable. Sold 20 for $140.0
# 02-28-2017's tonkotsu ramen = most expensive. A total cost of $120.0
#
# 03-01-2017's soft-shell miso crab ramen = most profitable. Sold 44 for $308.0
# 03-01-2017's soft-shell miso crab ramen = most expensive. A total cost of $308.0
#
# 03-02-2017's truffle butter ramen = most profitable. Sold 2 for $14.0
# 03-02-2017's truffle butter ramen = most expensive. A total cost of $14.0
#
# 03-03-2017's miso crab ramen = most profitable. Sold 36 for $216.0
# 03-03-2017's miso crab ramen = most expensive. A total cost of $216.0
#
# 03-04-2017's soft-shell miso crab ramen = most profitable. Sold 6 for $42.0
# 03-04-2017's soft-shell miso crab ramen = most expensive. A total cost of $42.0
#
# 03-05-2017's vegetarian spicy miso = most profitable. Sold 24 for $168.0
# 03-05-2017's vegetarian spicy miso = most expensive. A total cost of $120.0
#
# 03-06-2017's soft-shell miso crab ramen = most profitable. Sold 14 for $98.0
# 03-06-2017's soft-shell miso crab ramen = most expensive. A total cost of $98.0
#
# 03-07-2017's nagomi shoyu = most profitable. Sold 24 for $144.0
# 03-07-2017's truffle butter ramen = most expensive. A total cost of $140.0
#
# 03-08-2017's soft-shell miso crab ramen = most profitable. Sold 28 for $196.0
# 03-08-2017's soft-shell miso crab ramen = most expensive. A total cost of $196.0
#
# 03-09-2017's truffle butter ramen = most profitable. Sold 2 for $14.0
# 03-09-2017's truffle butter ramen = most expensive. A total cost of $14.0
#
# 03-10-2017's vegetarian curry + king trumpet mushroom ramen = most profitable. Sold 22 for $132.0
# 03-10-2017's vegetarian curry + king trumpet mushroom ramen = most expensive. A total cost of $154.0
#
# 03-11-2017's soft-shell miso crab ramen = most profitable. Sold 16 for $112.0
# 03-11-2017's soft-shell miso crab ramen = most expensive. A total cost of $112.0
#
# 03-12-2017's burnt garlic tonkotsu ramen = most profitable. Sold 24 for $192.0
# 03-12-2017's truffle butter ramen = most expensive. A total cost of $154.0
#
# 03-13-2017's spicy miso ramen = most profitable. Sold 18 for $126.0
# 03-13-2017's truffle butter ramen = most expensive. A total cost of $126.0
#
# 03-14-2017's burnt garlic tonkotsu ramen = most profitable. Sold 28 for $224.0
# 03-14-2017's soft-shell miso crab ramen = most expensive. A total cost of $196.0
#
# 03-15-2017's soft-shell miso crab ramen = most profitable. Sold 12 for $84.0
# 03-15-2017's soft-shell miso crab ramen = most expensive. A total cost of $84.0
#
# 03-16-2017's vegetarian spicy miso = most profitable. Sold 14 for $98.0
# 03-16-2017's vegetarian spicy miso = most expensive. A total cost of $70.0
#
# 03-17-2017's tonkotsu ramen = most profitable. Sold 12 for $84.0
# 03-17-2017's soft-shell miso crab ramen = most expensive. A total cost of $84.0
#
# 03-18-2017's burnt garlic tonkotsu ramen = most profitable. Sold 12 for $96.0
# 03-18-2017's burnt garlic tonkotsu ramen = most expensive. A total cost of $72.0
#
# 03-19-2017's burnt garlic tonkotsu ramen = most profitable. Sold 16 for $128.0
# 03-19-2017's burnt garlic tonkotsu ramen = most expensive. A total cost of $96.0
#
# 03-20-2017's spicy miso ramen = most profitable. Sold 34 for $238.0
# 03-20-2017's tonkotsu ramen = most expensive. A total cost of $192.0
#
# 03-21-2017's burnt garlic tonkotsu ramen = most profitable. Sold 30 for $240.0
# 03-21-2017's burnt garlic tonkotsu ramen = most expensive. A total cost of $180.0
#
# 03-22-2017's vegetarian spicy miso = most profitable. Sold 36 for $252.0
# 03-22-2017's vegetarian curry + king trumpet mushroom ramen = most expensive. A total cost of $210.0
#
# 03-23-2017's soft-shell miso crab ramen = most profitable. Sold 30 for $210.0
# 03-23-2017's soft-shell miso crab ramen = most expensive. A total cost of $210.0
#
# 03-24-2017's burnt garlic tonkotsu ramen = most profitable. Sold 22 for $176.0
# 03-24-2017's burnt garlic tonkotsu ramen = most expensive. A total cost of $132.0
#
# 03-25-2017's burnt garlic tonkotsu ramen = most profitable. Sold 8 for $64.0
# 03-25-2017's tori paitan ramen = most expensive. A total cost of $48.0
#
# 03-26-2017's tonkotsu ramen = most profitable. Sold 26 for $182.0
# 03-26-2017's tonkotsu ramen = most expensive. A total cost of $156.0
#
# 03-27-2017's burnt garlic tonkotsu ramen = most profitable. Sold 22 for $176.0
# 03-27-2017's burnt garlic tonkotsu ramen = most expensive. A total cost of $132.0
#
# 03-28-2017's truffle butter ramen = most profitable. Sold 24 for $168.0
# 03-28-2017's truffle butter ramen = most expensive. A total cost of $168.0
#
# 03-29-2017's burnt garlic tonkotsu ramen = most profitable. Sold 22 for $176.0
# 03-29-2017's truffle butter ramen = most expensive. A total cost of $140.0
#
# 03-30-2017's vegetarian spicy miso = most profitable. Sold 26 for $182.0
# 03-30-2017's vegetarian spicy miso = most expensive. A total cost of $130.0
#
# 03-31-2017's truffle butter ramen = most profitable. Sold 8 for $56.0
# 03-31-2017's truffle butter ramen = most expensive. A total cost of $56.0
#
# 04-01-2017's burnt garlic tonkotsu ramen = most profitable. Sold 22 for $176.0
# 04-01-2017's burnt garlic tonkotsu ramen = most expensive. A total cost of $132.0
#
# 04-02-2017's vegetarian curry + king trumpet mushroom ramen = most profitable. Sold 6 for $36.0
# 04-02-2017's vegetarian curry + king trumpet mushroom ramen = most expensive. A total cost of $42.0
#
# 04-03-2017's vegetarian spicy miso = most profitable. Sold 40 for $280.0
# 04-03-2017's miso crab ramen = most expensive. A total cost of $204.0
#
# 04-04-2017's soft-shell miso crab ramen = most profitable. Sold 32 for $224.0
# 04-04-2017's soft-shell miso crab ramen = most expensive. A total cost of $224.0
#
# 04-05-2017's tonkotsu ramen = most profitable. Sold 12 for $84.0
# 04-05-2017's miso crab ramen = most expensive. A total cost of $84.0
#
# 04-06-2017's truffle butter ramen = most profitable. Sold 32 for $224.0
# 04-06-2017's vegetarian curry + king trumpet mushroom ramen = most expensive. A total cost of $238.0
#
# 04-07-2017's burnt garlic tonkotsu ramen = most profitable. Sold 12 for $96.0
# 04-07-2017's burnt garlic tonkotsu ramen = most expensive. A total cost of $72.0
#
# 04-08-2017's shio ramen = most profitable. Sold 28 for $168.0
# 04-08-2017's shio ramen = most expensive. A total cost of $140.0
#
# 04-09-2017's spicy miso ramen = most profitable. Sold 32 for $224.0
# 04-09-2017's spicy miso ramen = most expensive. A total cost of $160.0
#
# 04-10-2017's spicy miso ramen = most profitable. Sold 22 for $154.0
# 04-10-2017's miso crab ramen = most expensive. A total cost of $132.0
#
# 04-11-2017's miso crab ramen = most profitable. Sold 36 for $216.0
# 04-11-2017's miso crab ramen = most expensive. A total cost of $216.0
#
# 04-12-2017's burnt garlic tonkotsu ramen = most profitable. Sold 8 for $64.0
# 04-12-2017's truffle butter ramen = most expensive. A total cost of $56.0
#
# 04-13-2017's spicy miso ramen = most profitable. Sold 16 for $112.0
# 04-13-2017's nagomi shoyu = most expensive. A total cost of $90.0
#
# 04-14-2017's spicy miso ramen = most profitable. Sold 38 for $266.0
# 04-14-2017's vegetarian curry + king trumpet mushroom ramen = most expensive. A total cost of $238.0
#
# 04-15-2017's soft-shell miso crab ramen = most profitable. Sold 22 for $154.0
# 04-15-2017's soft-shell miso crab ramen = most expensive. A total cost of $154.0
#
# 04-16-2017's shio ramen = most profitable. Sold 4 for $24.0
# 04-16-2017's shio ramen = most expensive. A total cost of $20.0
#
# 04-17-2017's spicy miso ramen = most profitable. Sold 32 for $224.0
# 04-17-2017's soft-shell miso crab ramen = most expensive. A total cost of $210.0
#
# 04-18-2017's truffle butter ramen = most profitable. Sold 22 for $154.0
# 04-18-2017's truffle butter ramen = most expensive. A total cost of $154.0
#
# 04-19-2017's shio ramen = most profitable. Sold 4 for $24.0
# 04-19-2017's shio ramen = most expensive. A total cost of $20.0
#
# 04-20-2017's vegetarian spicy miso = most profitable. Sold 16 for $112.0
# 04-20-2017's soft-shell miso crab ramen = most expensive. A total cost of $112.0
#
# 04-21-2017's tonkotsu ramen = most profitable. Sold 30 for $210.0
# 04-21-2017's vegetarian curry + king trumpet mushroom ramen = most expensive. A total cost of $196.0
#
# 04-22-2017's soft-shell miso crab ramen = most profitable. Sold 28 for $196.0
# 04-22-2017's soft-shell miso crab ramen = most expensive. A total cost of $196.0
#
# 04-23-2017's tori paitan ramen = most profitable. Sold 26 for $182.0
# 04-23-2017's tori paitan ramen = most expensive. A total cost of $156.0
#
# 04-24-2017's tonkotsu ramen = most profitable. Sold 30 for $210.0
# 04-24-2017's tonkotsu ramen = most expensive. A total cost of $180.0
#
# 04-25-2017's vegetarian spicy miso = most profitable. Sold 32 for $224.0
# 04-25-2017's vegetarian spicy miso = most expensive. A total cost of $160.0
#
# 04-26-2017's truffle butter ramen = most profitable. Sold 8 for $56.0
# 04-26-2017's truffle butter ramen = most expensive. A total cost of $56.0
#
# 04-27-2017's burnt garlic tonkotsu ramen = most profitable. Sold 26 for $208.0
# 04-27-2017's truffle butter ramen = most expensive. A total cost of $168.0
#
# 04-28-2017's spicy miso ramen = most profitable. Sold 34 for $238.0
# 04-28-2017's spicy miso ramen = most expensive. A total cost of $170.0
#
# 04-29-2017's soft-shell miso crab ramen = most profitable. Sold 14 for $98.0
# 04-29-2017's soft-shell miso crab ramen = most expensive. A total cost of $98.0
#
# 04-30-2017's truffle butter ramen = most profitable. Sold 16 for $112.0
# 04-30-2017's truffle butter ramen = most expensive. A total cost of $112.0
#
# 05-01-2017's tonkotsu ramen = most profitable. Sold 30 for $210.0
# 05-01-2017's tonkotsu ramen = most expensive. A total cost of $180.0
#
# 05-02-2017's miso crab ramen = most profitable. Sold 14 for $84.0
# 05-02-2017's miso crab ramen = most expensive. A total cost of $84.0
#
# 05-03-2017's soft-shell miso crab ramen = most profitable. Sold 30 for $210.0
# 05-03-2017's soft-shell miso crab ramen = most expensive. A total cost of $210.0
#
# 05-04-2017's vegetarian spicy miso = most profitable. Sold 18 for $126.0
# 05-04-2017's soft-shell miso crab ramen = most expensive. A total cost of $112.0
#
# 05-05-2017's vegetarian spicy miso = most profitable. Sold 28 for $196.0
# 05-05-2017's vegetarian spicy miso = most expensive. A total cost of $140.0
#
# 05-06-2017's truffle butter ramen = most profitable. Sold 36 for $252.0
# 05-06-2017's truffle butter ramen = most expensive. A total cost of $252.0
#
# 05-07-2017's truffle butter ramen = most profitable. Sold 28 for $196.0
# 05-07-2017's truffle butter ramen = most expensive. A total cost of $196.0
#
# 05-08-2017's tori paitan ramen = most profitable. Sold 26 for $182.0
# 05-08-2017's tori paitan ramen = most expensive. A total cost of $156.0
#
# 05-09-2017's truffle butter ramen = most profitable. Sold 30 for $210.0
# 05-09-2017's truffle butter ramen = most expensive. A total cost of $210.0
#
# 05-10-2017's spicy miso ramen = most profitable. Sold 2 for $14.0
# 05-10-2017's soft-shell miso crab ramen = most expensive. A total cost of $14.0
#
# 05-11-2017's truffle butter ramen = most profitable. Sold 26 for $182.0
# 05-11-2017's truffle butter ramen = most expensive. A total cost of $182.0
#
# 05-12-2017's tori paitan ramen = most profitable. Sold 8 for $56.0
# 05-12-2017's tori paitan ramen = most expensive. A total cost of $48.0
#
# 05-13-2017's nagomi shoyu = most profitable. Sold 8 for $48.0
# 05-13-2017's vegetarian curry + king trumpet mushroom ramen = most expensive. A total cost of $42.0
#
# 05-14-2017's burnt garlic tonkotsu ramen = most profitable. Sold 30 for $240.0
# 05-14-2017's miso crab ramen = most expensive. A total cost of $192.0
#
# 05-15-2017's tori paitan ramen = most profitable. Sold 36 for $252.0
# 05-15-2017's tori paitan ramen = most expensive. A total cost of $216.0
#
# 05-16-2017's nagomi shoyu = most profitable. Sold 12 for $72.0
# 05-16-2017's truffle butter ramen = most expensive. A total cost of $70.0
#
# 05-17-2017's miso crab ramen = most profitable. Sold 20 for $120.0
# 05-17-2017's miso crab ramen = most expensive. A total cost of $120.0
#
# 05-18-2017's shio ramen = most profitable. Sold 10 for $60.0
# 05-18-2017's shio ramen = most expensive. A total cost of $50.0
#
# 05-19-2017's truffle butter ramen = most profitable. Sold 6 for $42.0
# 05-19-2017's truffle butter ramen = most expensive. A total cost of $42.0
#
# 05-20-2017's vegetarian curry + king trumpet mushroom ramen = most profitable. Sold 26 for $156.0
# 05-20-2017's vegetarian curry + king trumpet mushroom ramen = most expensive. A total cost of $182.0
#
# 05-21-2017's soft-shell miso crab ramen = most profitable. Sold 32 for $224.0
# 05-21-2017's soft-shell miso crab ramen = most expensive. A total cost of $224.0
#
# 05-22-2017's vegetarian spicy miso = most profitable. Sold 46 for $322.0
# 05-22-2017's vegetarian spicy miso = most expensive. A total cost of $230.0
#
# 05-23-2017's miso crab ramen = most profitable. Sold 6 for $36.0
# 05-23-2017's miso crab ramen = most expensive. A total cost of $36.0
#
# 05-24-2017's truffle butter ramen = most profitable. Sold 32 for $224.0
# 05-24-2017's truffle butter ramen = most expensive. A total cost of $224.0
#
# 05-25-2017's burnt garlic tonkotsu ramen = most profitable. Sold 16 for $128.0
# 05-25-2017's soft-shell miso crab ramen = most expensive. A total cost of $112.0
#
# 05-26-2017's tonkotsu ramen = most profitable. Sold 40 for $280.0
# 05-26-2017's tonkotsu ramen = most expensive. A total cost of $240.0
#
# 05-27-2017's soft-shell miso crab ramen = most profitable. Sold 12 for $84.0
# 05-27-2017's soft-shell miso crab ramen = most expensive. A total cost of $84.0
#
# 05-28-2017's vegetarian spicy miso = most profitable. Sold 6 for $42.0
# 05-28-2017's vegetarian spicy miso = most expensive. A total cost of $30.0
#
# 05-30-2017's truffle butter ramen = most profitable. Sold 20 for $140.0
# 05-30-2017's truffle butter ramen = most expensive. A total cost of $140.0
#
# 05-31-2017's tori paitan ramen = most profitable. Sold 32 for $224.0
# 05-31-2017's tori paitan ramen = most expensive. A total cost of $192.0
#
# 06-02-2017's soft-shell miso crab ramen = most profitable. Sold 14 for $98.0
# 06-02-2017's soft-shell miso crab ramen = most expensive. A total cost of $98.0
#
# 06-03-2017's soft-shell miso crab ramen = most profitable. Sold 8 for $56.0
# 06-03-2017's soft-shell miso crab ramen = most expensive. A total cost of $56.0
#
# 06-04-2017's tonkotsu ramen = most profitable. Sold 32 for $224.0
# 06-04-2017's tonkotsu ramen = most expensive. A total cost of $192.0
#
# 06-05-2017's truffle butter ramen = most profitable. Sold 28 for $196.0
# 06-05-2017's truffle butter ramen = most expensive. A total cost of $196.0
#
# 06-06-2017's vegetarian spicy miso = most profitable. Sold 24 for $168.0
# 06-06-2017's vegetarian spicy miso = most expensive. A total cost of $120.0
#
# 06-07-2017's tonkotsu ramen = most profitable. Sold 46 for $322.0
# 06-07-2017's tonkotsu ramen = most expensive. A total cost of $276.0
#
# 06-08-2017's vegetarian curry + king trumpet mushroom ramen = most profitable. Sold 20 for $120.0
# 06-08-2017's vegetarian curry + king trumpet mushroom ramen = most expensive. A total cost of $140.0
#
# 06-09-2017's nagomi shoyu = most profitable. Sold 40 for $240.0
# 06-09-2017's nagomi shoyu = most expensive. A total cost of $200.0
#
# 06-10-2017's truffle butter ramen = most profitable. Sold 36 for $252.0
# 06-10-2017's truffle butter ramen = most expensive. A total cost of $252.0
#
# 06-11-2017's miso crab ramen = most profitable. Sold 40 for $240.0
# 06-11-2017's miso crab ramen = most expensive. A total cost of $240.0
#
# 06-12-2017's vegetarian spicy miso = most profitable. Sold 28 for $196.0
# 06-12-2017's vegetarian spicy miso = most expensive. A total cost of $140.0
#
# 06-13-2017's shio ramen = most profitable. Sold 18 for $108.0
# 06-13-2017's shio ramen = most expensive. A total cost of $90.0
#
# 06-14-2017's soft-shell miso crab ramen = most profitable. Sold 36 for $252.0
# 06-14-2017's soft-shell miso crab ramen = most expensive. A total cost of $252.0
#
# 06-15-2017's tonkotsu ramen = most profitable. Sold 8 for $56.0
# 06-15-2017's tonkotsu ramen = most expensive. A total cost of $48.0
#
# 06-16-2017's spicy miso ramen = most profitable. Sold 20 for $140.0
# 06-16-2017's vegetarian curry + king trumpet mushroom ramen = most expensive. A total cost of $140.0
#
# 06-17-2017's burnt garlic tonkotsu ramen = most profitable. Sold 20 for $160.0
# 06-17-2017's burnt garlic tonkotsu ramen = most expensive. A total cost of $120.0
#
# 06-18-2017's vegetarian curry + king trumpet mushroom ramen = most profitable. Sold 40 for $240.0
# 06-18-2017's vegetarian curry + king trumpet mushroom ramen = most expensive. A total cost of $280.0
#
# 06-19-2017's tonkotsu ramen = most profitable. Sold 34 for $238.0
# 06-19-2017's tonkotsu ramen = most expensive. A total cost of $204.0
#
# 06-20-2017's vegetarian spicy miso = most profitable. Sold 22 for $154.0
# 06-20-2017's vegetarian curry + king trumpet mushroom ramen = most expensive. A total cost of $126.0
#
# 06-21-2017's spicy miso ramen = most profitable. Sold 26 for $182.0
# 06-21-2017's spicy miso ramen = most expensive. A total cost of $130.0
#
# 06-22-2017's vegetarian curry + king trumpet mushroom ramen = most profitable. Sold 26 for $156.0
# 06-22-2017's vegetarian curry + king trumpet mushroom ramen = most expensive. A total cost of $182.0
#
# 06-23-2017's truffle butter ramen = most profitable. Sold 28 for $196.0
# 06-23-2017's truffle butter ramen = most expensive. A total cost of $196.0
#
# 06-24-2017's miso crab ramen = most profitable. Sold 26 for $156.0
# 06-24-2017's miso crab ramen = most expensive. A total cost of $156.0
#
# 06-25-2017's tonkotsu ramen = most profitable. Sold 12 for $84.0
# 06-25-2017's tonkotsu ramen = most expensive. A total cost of $72.0
#
# 06-26-2017's vegetarian curry + king trumpet mushroom ramen = most profitable. Sold 14 for $84.0
# 06-26-2017's vegetarian curry + king trumpet mushroom ramen = most expensive. A total cost of $98.0
#
# 06-27-2017's vegetarian curry + king trumpet mushroom ramen = most profitable. Sold 24 for $144.0
# 06-27-2017's vegetarian curry + king trumpet mushroom ramen = most expensive. A total cost of $168.0
#
# 06-28-2017's vegetarian curry + king trumpet mushroom ramen = most profitable. Sold 40 for $240.0
# 06-28-2017's vegetarian curry + king trumpet mushroom ramen = most expensive. A total cost of $280.0
#
# 06-29-2017's vegetarian curry + king trumpet mushroom ramen = most profitable. Sold 42 for $252.0
# 06-29-2017's vegetarian curry + king trumpet mushroom ramen = most expensive. A total cost of $294.0
#
# 06-30-2017's burnt garlic tonkotsu ramen = most profitable. Sold 8 for $64.0
# 06-30-2017's burnt garlic tonkotsu ramen = most expensive. A total cost of $48.0
#
# 07-01-2017's vegetarian spicy miso = most profitable. Sold 28 for $196.0
# 07-01-2017's vegetarian curry + king trumpet mushroom ramen = most expensive. A total cost of $154.0
#
# 07-02-2017's tori paitan ramen = most profitable. Sold 28 for $196.0
# 07-02-2017's tori paitan ramen = most expensive. A total cost of $168.0
#
# 07-03-2017's soft-shell miso crab ramen = most profitable. Sold 32 for $224.0
# 07-03-2017's soft-shell miso crab ramen = most expensive. A total cost of $224.0
#
# 07-04-2017's nagomi shoyu = most profitable. Sold 30 for $180.0
# 07-04-2017's nagomi shoyu = most expensive. A total cost of $150.0
#
# 07-05-2017's tonkotsu ramen = most profitable. Sold 24 for $168.0
# 07-05-2017's tonkotsu ramen = most expensive. A total cost of $144.0
#
# 07-06-2017's tori paitan ramen = most profitable. Sold 8 for $56.0
# 07-06-2017's vegetarian curry + king trumpet mushroom ramen = most expensive. A total cost of $56.0
#
# 07-07-2017's truffle butter ramen = most profitable. Sold 32 for $224.0
# 07-07-2017's truffle butter ramen = most expensive. A total cost of $224.0
#
# 07-08-2017's burnt garlic tonkotsu ramen = most profitable. Sold 32 for $256.0
# 07-08-2017's burnt garlic tonkotsu ramen = most expensive. A total cost of $192.0
#
# 07-09-2017's miso crab ramen = most profitable. Sold 4 for $24.0
# 07-09-2017's miso crab ramen = most expensive. A total cost of $24.0
#
# 07-10-2017's tori paitan ramen = most profitable. Sold 14 for $98.0
# 07-10-2017's tori paitan ramen = most expensive. A total cost of $84.0
#
# 07-11-2017's truffle butter ramen = most profitable. Sold 24 for $168.0
# 07-11-2017's truffle butter ramen = most expensive. A total cost of $168.0
#
# 07-12-2017's spicy miso ramen = most profitable. Sold 2 for $14.0
# 07-12-2017's soft-shell miso crab ramen = most expensive. A total cost of $14.0
#
# 07-13-2017's spicy miso ramen = most profitable. Sold 44 for $308.0
# 07-13-2017's spicy miso ramen = most expensive. A total cost of $220.0
#
# 07-14-2017's spicy miso ramen = most profitable. Sold 32 for $224.0
# 07-14-2017's miso crab ramen = most expensive. A total cost of $180.0
#
# 07-15-2017's burnt garlic tonkotsu ramen = most profitable. Sold 22 for $176.0
# 07-15-2017's burnt garlic tonkotsu ramen = most expensive. A total cost of $132.0
#
# 07-16-2017's vegetarian curry + king trumpet mushroom ramen = most profitable. Sold 18 for $108.0
# 07-16-2017's vegetarian curry + king trumpet mushroom ramen = most expensive. A total cost of $126.0
#
# 07-17-2017's truffle butter ramen = most profitable. Sold 48 for $336.0
# 07-17-2017's truffle butter ramen = most expensive. A total cost of $336.0
#
# 07-18-2017's tori paitan ramen = most profitable. Sold 28 for $196.0
# 07-18-2017's soft-shell miso crab ramen = most expensive. A total cost of $182.0
#
# 07-19-2017's spicy miso ramen = most profitable. Sold 14 for $98.0
# 07-19-2017's spicy miso ramen = most expensive. A total cost of $70.0
#
# 07-20-2017's burnt garlic tonkotsu ramen = most profitable. Sold 36 for $288.0
# 07-20-2017's burnt garlic tonkotsu ramen = most expensive. A total cost of $216.0
#
# 07-21-2017's burnt garlic tonkotsu ramen = most profitable. Sold 36 for $288.0
# 07-21-2017's burnt garlic tonkotsu ramen = most expensive. A total cost of $216.0
#
# 07-22-2017's burnt garlic tonkotsu ramen = most profitable. Sold 26 for $208.0
# 07-22-2017's soft-shell miso crab ramen = most expensive. A total cost of $168.0
#
# 07-23-2017's burnt garlic tonkotsu ramen = most profitable. Sold 28 for $224.0
# 07-23-2017's vegetarian curry + king trumpet mushroom ramen = most expensive. A total cost of $238.0
#
# 07-24-2017's tonkotsu ramen = most profitable. Sold 26 for $182.0
# 07-24-2017's tonkotsu ramen = most expensive. A total cost of $156.0
#
# 07-25-2017's burnt garlic tonkotsu ramen = most profitable. Sold 30 for $240.0
# 07-25-2017's burnt garlic tonkotsu ramen = most expensive. A total cost of $180.0
#
# 07-26-2017's spicy miso ramen = most profitable. Sold 18 for $126.0
# 07-26-2017's soft-shell miso crab ramen = most expensive. A total cost of $98.0
#
# 07-27-2017's burnt garlic tonkotsu ramen = most profitable. Sold 32 for $256.0
# 07-27-2017's burnt garlic tonkotsu ramen = most expensive. A total cost of $192.0
#
# 07-28-2017's spicy miso ramen = most profitable. Sold 20 for $140.0
# 07-28-2017's soft-shell miso crab ramen = most expensive. A total cost of $126.0
#
# 07-29-2017's vegetarian spicy miso = most profitable. Sold 12 for $84.0
# 07-29-2017's miso crab ramen = most expensive. A total cost of $72.0
#
# 07-30-2017's shio ramen = most profitable. Sold 8 for $48.0
# 07-30-2017's shio ramen = most expensive. A total cost of $40.0
#
# 07-31-2017's vegetarian spicy miso = most profitable. Sold 32 for $224.0
# 07-31-2017's soft-shell miso crab ramen = most expensive. A total cost of $168.0
#
# 08-01-2017's spicy miso ramen = most profitable. Sold 34 for $238.0
# 08-01-2017's spicy miso ramen = most expensive. A total cost of $170.0
#
# 08-02-2017's tonkotsu ramen = most profitable. Sold 12 for $84.0
# 08-02-2017's miso crab ramen = most expensive. A total cost of $84.0
#
# 08-03-2017's spicy miso ramen = most profitable. Sold 34 for $238.0
# 08-03-2017's truffle butter ramen = most expensive. A total cost of $196.0
#
# 08-04-2017's tori paitan ramen = most profitable. Sold 38 for $266.0
# 08-04-2017's tori paitan ramen = most expensive. A total cost of $228.0
#
# 08-05-2017's truffle butter ramen = most profitable. Sold 6 for $42.0
# 08-05-2017's truffle butter ramen = most expensive. A total cost of $42.0
#
# 08-06-2017's tonkotsu ramen = most profitable. Sold 8 for $56.0
# 08-06-2017's tonkotsu ramen = most expensive. A total cost of $48.0
#
# 08-07-2017's soft-shell miso crab ramen = most profitable. Sold 10 for $70.0
# 08-07-2017's soft-shell miso crab ramen = most expensive. A total cost of $70.0
#
# 08-08-2017's shio ramen = most profitable. Sold 6 for $36.0
# 08-08-2017's shio ramen = most expensive. A total cost of $30.0
#
# 08-09-2017's soft-shell miso crab ramen = most profitable. Sold 12 for $84.0
# 08-09-2017's soft-shell miso crab ramen = most expensive. A total cost of $84.0
#
# 08-10-2017's vegetarian spicy miso = most profitable. Sold 34 for $238.0
# 08-10-2017's vegetarian spicy miso = most expensive. A total cost of $170.0
#
# 08-11-2017's spicy miso ramen = most profitable. Sold 28 for $196.0
# 08-11-2017's miso crab ramen = most expensive. A total cost of $180.0
#
# 08-12-2017's shio ramen = most profitable. Sold 40 for $240.0
# 08-12-2017's shio ramen = most expensive. A total cost of $200.0
#
# 08-13-2017's vegetarian spicy miso = most profitable. Sold 24 for $168.0
# 08-13-2017's vegetarian spicy miso = most expensive. A total cost of $120.0
#
# 08-14-2017's tori paitan ramen = most profitable. Sold 24 for $168.0
# 08-14-2017's tori paitan ramen = most expensive. A total cost of $144.0
#
# 08-15-2017's vegetarian spicy miso = most profitable. Sold 26 for $182.0
# 08-15-2017's vegetarian spicy miso = most expensive. A total cost of $130.0
#
# 08-16-2017's burnt garlic tonkotsu ramen = most profitable. Sold 2 for $16.0
# 08-16-2017's burnt garlic tonkotsu ramen = most expensive. A total cost of $12.0
#
# 08-17-2017's burnt garlic tonkotsu ramen = most profitable. Sold 8 for $64.0
# 08-17-2017's truffle butter ramen = most expensive. A total cost of $56.0
#
# 08-18-2017's burnt garlic tonkotsu ramen = most profitable. Sold 18 for $144.0
# 08-18-2017's miso crab ramen = most expensive. A total cost of $144.0
#
# 08-19-2017's shio ramen = most profitable. Sold 36 for $216.0
# 08-19-2017's vegetarian curry + king trumpet mushroom ramen = most expensive. A total cost of $182.0
#
# 08-20-2017's vegetarian spicy miso = most profitable. Sold 4 for $28.0
# 08-20-2017's vegetarian spicy miso = most expensive. A total cost of $20.0
#
# 08-21-2017's shio ramen = most profitable. Sold 32 for $192.0
# 08-21-2017's vegetarian curry + king trumpet mushroom ramen = most expensive. A total cost of $182.0
#
# 08-22-2017's tonkotsu ramen = most profitable. Sold 28 for $196.0
# 08-22-2017's soft-shell miso crab ramen = most expensive. A total cost of $182.0
#
# 08-23-2017's tonkotsu ramen = most profitable. Sold 28 for $196.0
# 08-23-2017's tonkotsu ramen = most expensive. A total cost of $168.0
#
# 08-24-2017's shio ramen = most profitable. Sold 26 for $156.0
# 08-24-2017's shio ramen = most expensive. A total cost of $130.0
#
# 08-25-2017's vegetarian curry + king trumpet mushroom ramen = most profitable. Sold 12 for $72.0
# 08-25-2017's vegetarian curry + king trumpet mushroom ramen = most expensive. A total cost of $84.0
#
# 08-26-2017's nagomi shoyu = most profitable. Sold 32 for $192.0
# 08-26-2017's nagomi shoyu = most expensive. A total cost of $160.0
#
# 08-27-2017's burnt garlic tonkotsu ramen = most profitable. Sold 14 for $112.0
# 08-27-2017's truffle butter ramen = most expensive. A total cost of $112.0
#
# 08-28-2017's burnt garlic tonkotsu ramen = most profitable. Sold 28 for $224.0
# 08-28-2017's soft-shell miso crab ramen = most expensive. A total cost of $182.0
#
# 08-29-2017's spicy miso ramen = most profitable. Sold 40 for $280.0
# 08-29-2017's spicy miso ramen = most expensive. A total cost of $200.0
#
# 08-30-2017's tori paitan ramen = most profitable. Sold 10 for $70.0
# 08-30-2017's vegetarian curry + king trumpet mushroom ramen = most expensive. A total cost of $70.0
#
# 08-31-2017's shio ramen = most profitable. Sold 30 for $180.0
# 08-31-2017's vegetarian curry + king trumpet mushroom ramen = most expensive. A total cost of $154.0
#
# 09-01-2017's vegetarian curry + king trumpet mushroom ramen = most profitable. Sold 44 for $264.0
# 09-01-2017's vegetarian curry + king trumpet mushroom ramen = most expensive. A total cost of $308.0
#
# 09-02-2017's shio ramen = most profitable. Sold 32 for $192.0
# 09-02-2017's shio ramen = most expensive. A total cost of $160.0
#
# 09-03-2017's burnt garlic tonkotsu ramen = most profitable. Sold 32 for $256.0
# 09-03-2017's burnt garlic tonkotsu ramen = most expensive. A total cost of $192.0
#
# 09-04-2017's spicy miso ramen = most profitable. Sold 42 for $294.0
# 09-04-2017's spicy miso ramen = most expensive. A total cost of $210.0
#
# 09-05-2017's truffle butter ramen = most profitable. Sold 16 for $112.0
# 09-05-2017's truffle butter ramen = most expensive. A total cost of $112.0
#
# 09-06-2017's tori paitan ramen = most profitable. Sold 18 for $126.0
# 09-06-2017's tori paitan ramen = most expensive. A total cost of $108.0
#
# 09-07-2017's tori paitan ramen = most profitable. Sold 18 for $126.0
# 09-07-2017's tori paitan ramen = most expensive. A total cost of $108.0
#
# 09-08-2017's shio ramen = most profitable. Sold 6 for $36.0
# 09-08-2017's shio ramen = most expensive. A total cost of $30.0
#
# 09-09-2017's tori paitan ramen = most profitable. Sold 28 for $196.0
# 09-09-2017's vegetarian curry + king trumpet mushroom ramen = most expensive. A total cost of $196.0
#
# 09-10-2017's truffle butter ramen = most profitable. Sold 34 for $238.0
# 09-10-2017's truffle butter ramen = most expensive. A total cost of $238.0
#
# 09-11-2017's burnt garlic tonkotsu ramen = most profitable. Sold 20 for $160.0
# 09-11-2017's miso crab ramen = most expensive. A total cost of $132.0
#
# 09-12-2017's tonkotsu ramen = most profitable. Sold 38 for $266.0
# 09-12-2017's tonkotsu ramen = most expensive. A total cost of $228.0
#
# 09-13-2017's truffle butter ramen = most profitable. Sold 30 for $210.0
# 09-13-2017's truffle butter ramen = most expensive. A total cost of $210.0
#
# 09-14-2017's nagomi shoyu = most profitable. Sold 38 for $228.0
# 09-14-2017's truffle butter ramen = most expensive. A total cost of $210.0
#
# 09-15-2017's miso crab ramen = most profitable. Sold 32 for $192.0
# 09-15-2017's miso crab ramen = most expensive. A total cost of $192.0
#
# 09-16-2017's burnt garlic tonkotsu ramen = most profitable. Sold 34 for $272.0
# 09-16-2017's soft-shell miso crab ramen = most expensive. A total cost of $210.0
#
# 09-17-2017's truffle butter ramen = most profitable. Sold 34 for $238.0
# 09-17-2017's truffle butter ramen = most expensive. A total cost of $238.0
#
# 09-19-2017's tori paitan ramen = most profitable. Sold 30 for $210.0
# 09-19-2017's tori paitan ramen = most expensive. A total cost of $180.0
#
# 09-20-2017's truffle butter ramen = most profitable. Sold 26 for $182.0
# 09-20-2017's truffle butter ramen = most expensive. A total cost of $182.0
#
# 09-21-2017's shio ramen = most profitable. Sold 34 for $204.0
# 09-21-2017's shio ramen = most expensive. A total cost of $170.0
#
# 09-22-2017's burnt garlic tonkotsu ramen = most profitable. Sold 10 for $80.0
# 09-22-2017's vegetarian curry + king trumpet mushroom ramen = most expensive. A total cost of $84.0
#
# 09-23-2017's vegetarian spicy miso = most profitable. Sold 24 for $168.0
# 09-23-2017's truffle butter ramen = most expensive. A total cost of $140.0
#
# 09-24-2017's vegetarian spicy miso = most profitable. Sold 4 for $28.0
# 09-24-2017's vegetarian curry + king trumpet mushroom ramen = most expensive. A total cost of $28.0
#
# 09-25-2017's burnt garlic tonkotsu ramen = most profitable. Sold 18 for $144.0
# 09-25-2017's burnt garlic tonkotsu ramen = most expensive. A total cost of $108.0
#
# 09-26-2017's burnt garlic tonkotsu ramen = most profitable. Sold 2 for $16.0
# 09-26-2017's truffle butter ramen = most expensive. A total cost of $14.0
#
# 09-27-2017's burnt garlic tonkotsu ramen = most profitable. Sold 22 for $176.0
# 09-27-2017's tori paitan ramen = most expensive. A total cost of $144.0
#
# 09-28-2017's burnt garlic tonkotsu ramen = most profitable. Sold 28 for $224.0
# 09-28-2017's vegetarian curry + king trumpet mushroom ramen = most expensive. A total cost of $210.0
#
# 09-29-2017's vegetarian spicy miso = most profitable. Sold 24 for $168.0
# 09-29-2017's vegetarian spicy miso = most expensive. A total cost of $120.0
#
# 09-30-2017's burnt garlic tonkotsu ramen = most profitable. Sold 2 for $16.0
# 09-30-2017's tori paitan ramen = most expensive. A total cost of $12.0
#
# 10-01-2017's tonkotsu ramen = most profitable. Sold 22 for $154.0
# 10-01-2017's tonkotsu ramen = most expensive. A total cost of $132.0
#
# 10-02-2017's tonkotsu ramen = most profitable. Sold 12 for $84.0
# 10-02-2017's vegetarian curry + king trumpet mushroom ramen = most expensive. A total cost of $84.0
#
# 10-03-2017's nagomi shoyu = most profitable. Sold 42 for $252.0
# 10-03-2017's nagomi shoyu = most expensive. A total cost of $210.0
#
# 10-04-2017's truffle butter ramen = most profitable. Sold 4 for $28.0
# 10-04-2017's truffle butter ramen = most expensive. A total cost of $28.0
#
# 10-05-2017's burnt garlic tonkotsu ramen = most profitable. Sold 18 for $144.0
# 10-05-2017's truffle butter ramen = most expensive. A total cost of $112.0
#
# 10-06-2017's burnt garlic tonkotsu ramen = most profitable. Sold 18 for $144.0
# 10-06-2017's soft-shell miso crab ramen = most expensive. A total cost of $126.0
#
# 10-07-2017's burnt garlic tonkotsu ramen = most profitable. Sold 32 for $256.0
# 10-07-2017's vegetarian curry + king trumpet mushroom ramen = most expensive. A total cost of $252.0
#
# 10-08-2017's burnt garlic tonkotsu ramen = most profitable. Sold 12 for $96.0
# 10-08-2017's vegetarian curry + king trumpet mushroom ramen = most expensive. A total cost of $112.0
#
# 10-09-2017's soft-shell miso crab ramen = most profitable. Sold 6 for $42.0
# 10-09-2017's soft-shell miso crab ramen = most expensive. A total cost of $42.0
#
# 10-10-2017's soft-shell miso crab ramen = most profitable. Sold 10 for $70.0
# 10-10-2017's soft-shell miso crab ramen = most expensive. A total cost of $70.0
#
# 10-11-2017's vegetarian spicy miso = most profitable. Sold 6 for $42.0
# 10-11-2017's soft-shell miso crab ramen = most expensive. A total cost of $42.0
#
# 10-12-2017's tori paitan ramen = most profitable. Sold 28 for $196.0
# 10-12-2017's tori paitan ramen = most expensive. A total cost of $168.0
#
# 10-13-2017's soft-shell miso crab ramen = most profitable. Sold 8 for $56.0
# 10-13-2017's soft-shell miso crab ramen = most expensive. A total cost of $56.0
#
# 10-14-2017's soft-shell miso crab ramen = most profitable. Sold 12 for $84.0
# 10-14-2017's soft-shell miso crab ramen = most expensive. A total cost of $84.0
#
# 10-15-2017's burnt garlic tonkotsu ramen = most profitable. Sold 10 for $80.0
# 10-15-2017's burnt garlic tonkotsu ramen = most expensive. A total cost of $60.0
#
# 10-16-2017's vegetarian spicy miso = most profitable. Sold 28 for $196.0
# 10-16-2017's tori paitan ramen = most expensive. A total cost of $156.0
#
# 10-17-2017's nagomi shoyu = most profitable. Sold 8 for $48.0
# 10-17-2017's nagomi shoyu = most expensive. A total cost of $40.0
#
# 10-18-2017's soft-shell miso crab ramen = most profitable. Sold 24 for $168.0
# 10-18-2017's soft-shell miso crab ramen = most expensive. A total cost of $168.0
#
# 10-19-2017's vegetarian spicy miso = most profitable. Sold 4 for $28.0
# 10-19-2017's vegetarian spicy miso = most expensive. A total cost of $20.0
#
# 10-20-2017's tori paitan ramen = most profitable. Sold 14 for $98.0
# 10-20-2017's vegetarian curry + king trumpet mushroom ramen = most expensive. A total cost of $98.0
#
# 10-21-2017's tonkotsu ramen = most profitable. Sold 38 for $266.0
# 10-21-2017's tonkotsu ramen = most expensive. A total cost of $228.0
#
# 10-22-2017's tonkotsu ramen = most profitable. Sold 26 for $182.0
# 10-22-2017's tonkotsu ramen = most expensive. A total cost of $156.0
#
# 10-23-2017's nagomi shoyu = most profitable. Sold 24 for $144.0
# 10-23-2017's truffle butter ramen = most expensive. A total cost of $126.0
#
# 10-24-2017's vegetarian spicy miso = most profitable. Sold 36 for $252.0
# 10-24-2017's tonkotsu ramen = most expensive. A total cost of $204.0
#
# 10-25-2017's tori paitan ramen = most profitable. Sold 24 for $168.0
# 10-25-2017's tori paitan ramen = most expensive. A total cost of $144.0
#
# 10-26-2017's spicy miso ramen = most profitable. Sold 36 for $252.0
# 10-26-2017's soft-shell miso crab ramen = most expensive. A total cost of $196.0
#
# 10-27-2017's truffle butter ramen = most profitable. Sold 20 for $140.0
# 10-27-2017's vegetarian curry + king trumpet mushroom ramen = most expensive. A total cost of $154.0
#
# 10-28-2017's tori paitan ramen = most profitable. Sold 26 for $182.0
# 10-28-2017's tori paitan ramen = most expensive. A total cost of $156.0
#
# 10-29-2017's burnt garlic tonkotsu ramen = most profitable. Sold 32 for $256.0
# 10-29-2017's soft-shell miso crab ramen = most expensive. A total cost of $224.0
#
# 10-30-2017's tonkotsu ramen = most profitable. Sold 32 for $224.0
# 10-30-2017's tonkotsu ramen = most expensive. A total cost of $192.0
#
# 10-31-2017's tori paitan ramen = most profitable. Sold 36 for $252.0
# 10-31-2017's truffle butter ramen = most expensive. A total cost of $224.0
#
# 11-01-2017's soft-shell miso crab ramen = most profitable. Sold 24 for $168.0
# 11-01-2017's soft-shell miso crab ramen = most expensive. A total cost of $168.0
#
# 11-02-2017's spicy miso ramen = most profitable. Sold 46 for $322.0
# 11-02-2017's spicy miso ramen = most expensive. A total cost of $230.0
#
# 11-03-2017's shio ramen = most profitable. Sold 34 for $204.0
# 11-03-2017's shio ramen = most expensive. A total cost of $170.0
#
# 11-04-2017's burnt garlic tonkotsu ramen = most profitable. Sold 42 for $336.0
# 11-04-2017's burnt garlic tonkotsu ramen = most expensive. A total cost of $252.0
#
# 11-05-2017's miso crab ramen = most profitable. Sold 38 for $228.0
# 11-05-2017's miso crab ramen = most expensive. A total cost of $228.0
#
# 11-06-2017's tonkotsu ramen = most profitable. Sold 34 for $238.0
# 11-06-2017's soft-shell miso crab ramen = most expensive. A total cost of $210.0
#
# 11-07-2017's truffle butter ramen = most profitable. Sold 16 for $112.0
# 11-07-2017's truffle butter ramen = most expensive. A total cost of $112.0
#
# 11-08-2017's soft-shell miso crab ramen = most profitable. Sold 12 for $84.0
# 11-08-2017's soft-shell miso crab ramen = most expensive. A total cost of $84.0
#
# 11-09-2017's tori paitan ramen = most profitable. Sold 18 for $126.0
# 11-09-2017's soft-shell miso crab ramen = most expensive. A total cost of $126.0
#
# 11-10-2017's vegetarian curry + king trumpet mushroom ramen = most profitable. Sold 6 for $36.0
# 11-10-2017's vegetarian curry + king trumpet mushroom ramen = most expensive. A total cost of $42.0
#
# 11-11-2017's tori paitan ramen = most profitable. Sold 32 for $224.0
# 11-11-2017's truffle butter ramen = most expensive. A total cost of $210.0
#
# 11-12-2017's burnt garlic tonkotsu ramen = most profitable. Sold 20 for $160.0
# 11-12-2017's burnt garlic tonkotsu ramen = most expensive. A total cost of $120.0
#
# ...
#
# 09-18-2018's tonkotsu ramen = most profitable. Sold 34 for $238.0
# 09-18-2018's tonkotsu ramen = most expensive. A total cost of $204.0
#
# 09-19-2018's spicy miso ramen = most profitable. Sold 48 for $336.0
# 09-19-2018's spicy miso ramen = most expensive. A total cost of $240.0
#
# 09-20-2018's spicy miso ramen = most profitable. Sold 34 for $238.0
# 09-20-2018's spicy miso ramen = most expensive. A total cost of $170.0
#
# 09-21-2018's shio ramen = most profitable. Sold 26 for $156.0
# 09-21-2018's vegetarian curry + king trumpet mushroom ramen = most expensive. A total cost of $154.0
#
# 09-22-2018's shio ramen = most profitable. Sold 14 for $84.0
# 09-22-2018's shio ramen = most expensive. A total cost of $70.0
#
# 09-23-2018's tori paitan ramen = most profitable. Sold 16 for $112.0
# 09-23-2018's vegetarian curry + king trumpet mushroom ramen = most expensive. A total cost of $98.0
#
# 09-24-2018's vegetarian curry + king trumpet mushroom ramen = most profitable. Sold 30 for $180.0
# 09-24-2018's vegetarian curry + king trumpet mushroom ramen = most expensive. A total cost of $210.0
#
# 09-25-2018's burnt garlic tonkotsu ramen = most profitable. Sold 26 for $208.0
# 09-25-2018's tonkotsu ramen = most expensive. A total cost of $168.0
#
# 09-26-2018's nagomi shoyu = most profitable. Sold 34 for $204.0
# 09-26-2018's nagomi shoyu = most expensive. A total cost of $170.0
#
# 09-27-2018's vegetarian spicy miso = most profitable. Sold 26 for $182.0
# 09-27-2018's vegetarian curry + king trumpet mushroom ramen = most expensive. A total cost of $196.0
#
# 09-28-2018's vegetarian spicy miso = most profitable. Sold 14 for $98.0
# 09-28-2018's vegetarian spicy miso = most expensive. A total cost of $70.0
#
# 09-29-2018's shio ramen = most profitable. Sold 44 for $264.0
# 09-29-2018's shio ramen = most expensive. A total cost of $220.0
#
# 09-30-2018's tori paitan ramen = most profitable. Sold 30 for $210.0
# 09-30-2018's tori paitan ramen = most expensive. A total cost of $180.0
#
# 10-01-2018's tori paitan ramen = most profitable. Sold 18 for $126.0
# 10-01-2018's tori paitan ramen = most expensive. A total cost of $108.0
#
# 10-02-2018's burnt garlic tonkotsu ramen = most profitable. Sold 32 for $256.0
# 10-02-2018's vegetarian curry + king trumpet mushroom ramen = most expensive. A total cost of $280.0
#
# 10-03-2018's nagomi shoyu = most profitable. Sold 22 for $132.0
# 10-03-2018's vegetarian curry + king trumpet mushroom ramen = most expensive. A total cost of $126.0
#
# 10-04-2018's burnt garlic tonkotsu ramen = most profitable. Sold 30 for $240.0
# 10-04-2018's burnt garlic tonkotsu ramen = most expensive. A total cost of $180.0
#
# 10-05-2018's soft-shell miso crab ramen = most profitable. Sold 38 for $266.0
# 10-05-2018's soft-shell miso crab ramen = most expensive. A total cost of $266.0
#
# 10-06-2018's burnt garlic tonkotsu ramen = most profitable. Sold 24 for $192.0
# 10-06-2018's vegetarian curry + king trumpet mushroom ramen = most expensive. A total cost of $210.0
#
# 10-07-2018's vegetarian spicy miso = most profitable. Sold 10 for $70.0
# 10-07-2018's vegetarian curry + king trumpet mushroom ramen = most expensive. A total cost of $70.0
#
# 10-08-2018's burnt garlic tonkotsu ramen = most profitable. Sold 22 for $176.0
# 10-08-2018's burnt garlic tonkotsu ramen = most expensive. A total cost of $132.0
#
# 10-09-2018's truffle butter ramen = most profitable. Sold 20 for $140.0
# 10-09-2018's truffle butter ramen = most expensive. A total cost of $140.0
#
# 10-10-2018's truffle butter ramen = most profitable. Sold 28 for $196.0
# 10-10-2018's truffle butter ramen = most expensive. A total cost of $196.0
#
# 10-11-2018's spicy miso ramen = most profitable. Sold 22 for $154.0
# 10-11-2018's spicy miso ramen = most expensive. A total cost of $110.0
#
# 10-12-2018's vegetarian spicy miso = most profitable. Sold 8 for $56.0
# 10-12-2018's tori paitan ramen = most expensive. A total cost of $48.0
#
# 10-13-2018's miso crab ramen = most profitable. Sold 10 for $60.0
# 10-13-2018's miso crab ramen = most expensive. A total cost of $60.0
#
# 10-14-2018's nagomi shoyu = most profitable. Sold 24 for $144.0
# 10-14-2018's nagomi shoyu = most expensive. A total cost of $120.0
#
# 10-15-2018's burnt garlic tonkotsu ramen = most profitable. Sold 2 for $16.0
# 10-15-2018's burnt garlic tonkotsu ramen = most expensive. A total cost of $12.0
#
# 10-16-2018's burnt garlic tonkotsu ramen = most profitable. Sold 4 for $32.0
# 10-16-2018's burnt garlic tonkotsu ramen = most expensive. A total cost of $24.0
#
# 10-17-2018's shio ramen = most profitable. Sold 20 for $120.0
# 10-17-2018's shio ramen = most expensive. A total cost of $100.0
#
# 10-18-2018's spicy miso ramen = most profitable. Sold 36 for $252.0
# 10-18-2018's miso crab ramen = most expensive. A total cost of $204.0
#
# 10-19-2018's spicy miso ramen = most profitable. Sold 34 for $238.0
# 10-19-2018's miso crab ramen = most expensive. A total cost of $204.0
#
# 10-20-2018's truffle butter ramen = most profitable. Sold 18 for $126.0
# 10-20-2018's vegetarian curry + king trumpet mushroom ramen = most expensive. A total cost of $140.0
#
# 10-21-2018's spicy miso ramen = most profitable. Sold 24 for $168.0
# 10-21-2018's vegetarian curry + king trumpet mushroom ramen = most expensive. A total cost of $182.0
#
# 10-22-2018's spicy miso ramen = most profitable. Sold 24 for $168.0
# 10-22-2018's spicy miso ramen = most expensive. A total cost of $120.0
#
# 10-23-2018's truffle butter ramen = most profitable. Sold 16 for $112.0
# 10-23-2018's truffle butter ramen = most expensive. A total cost of $112.0
#
# 10-24-2018's vegetarian spicy miso = most profitable. Sold 28 for $196.0
# 10-24-2018's vegetarian curry + king trumpet mushroom ramen = most expensive. A total cost of $154.0
#
# 10-25-2018's soft-shell miso crab ramen = most profitable. Sold 12 for $84.0
# 10-25-2018's soft-shell miso crab ramen = most expensive. A total cost of $84.0
#
# 10-26-2018's vegetarian spicy miso = most profitable. Sold 30 for $210.0
# 10-26-2018's vegetarian curry + king trumpet mushroom ramen = most expensive. A total cost of $154.0
#
# 10-27-2018's burnt garlic tonkotsu ramen = most profitable. Sold 26 for $208.0
# 10-27-2018's burnt garlic tonkotsu ramen = most expensive. A total cost of $156.0
#
# 10-28-2018's soft-shell miso crab ramen = most profitable. Sold 12 for $84.0
# 10-28-2018's soft-shell miso crab ramen = most expensive. A total cost of $84.0
#
# 10-29-2018's burnt garlic tonkotsu ramen = most profitable. Sold 30 for $240.0
# 10-29-2018's vegetarian curry + king trumpet mushroom ramen = most expensive. A total cost of $224.0
#
# 10-30-2018's tonkotsu ramen = most profitable. Sold 10 for $70.0
# 10-30-2018's tonkotsu ramen = most expensive. A total cost of $60.0
#
# 10-31-2018's vegetarian spicy miso = most profitable. Sold 20 for $140.0
# 10-31-2018's truffle butter ramen = most expensive. A total cost of $126.0
#
# 11-01-2018's spicy miso ramen = most profitable. Sold 10 for $70.0
# 11-01-2018's truffle butter ramen = most expensive. A total cost of $70.0
#
# 11-02-2018's truffle butter ramen = most profitable. Sold 28 for $196.0
# 11-02-2018's truffle butter ramen = most expensive. A total cost of $196.0
#
# 11-03-2018's miso crab ramen = most profitable. Sold 40 for $240.0
# 11-03-2018's miso crab ramen = most expensive. A total cost of $240.0
#
# 11-04-2018's spicy miso ramen = most profitable. Sold 24 for $168.0
# 11-04-2018's truffle butter ramen = most expensive. A total cost of $154.0
#
# 11-05-2018's miso crab ramen = most profitable. Sold 8 for $48.0
# 11-05-2018's miso crab ramen = most expensive. A total cost of $48.0
#
# 11-06-2018's tori paitan ramen = most profitable. Sold 4 for $28.0
# 11-06-2018's soft-shell miso crab ramen = most expensive. A total cost of $28.0
#
# 11-07-2018's tori paitan ramen = most profitable. Sold 42 for $294.0
# 11-07-2018's tori paitan ramen = most expensive. A total cost of $252.0
#
# 11-08-2018's vegetarian spicy miso = most profitable. Sold 28 for $196.0
# 11-08-2018's tori paitan ramen = most expensive. A total cost of $144.0
#
# 11-09-2018's shio ramen = most profitable. Sold 32 for $192.0
# 11-09-2018's shio ramen = most expensive. A total cost of $160.0
#
# 11-10-2018's vegetarian spicy miso = most profitable. Sold 30 for $210.0
# 11-10-2018's soft-shell miso crab ramen = most expensive. A total cost of $168.0
#
# 11-11-2018's miso crab ramen = most profitable. Sold 30 for $180.0
# 11-11-2018's miso crab ramen = most expensive. A total cost of $180.0
#
# 11-12-2018's spicy miso ramen = most profitable. Sold 30 for $210.0
# 11-12-2018's spicy miso ramen = most expensive. A total cost of $150.0
#
# 11-13-2018's tori paitan ramen = most profitable. Sold 14 for $98.0
# 11-13-2018's tori paitan ramen = most expensive. A total cost of $84.0
#
# 11-14-2018's tonkotsu ramen = most profitable. Sold 24 for $168.0
# 11-14-2018's tonkotsu ramen = most expensive. A total cost of $144.0
#
# 11-15-2018's soft-shell miso crab ramen = most profitable. Sold 24 for $168.0
# 11-15-2018's soft-shell miso crab ramen = most expensive. A total cost of $168.0
#
# 11-16-2018's truffle butter ramen = most profitable. Sold 10 for $70.0
# 11-16-2018's truffle butter ramen = most expensive. A total cost of $70.0
#
# 11-17-2018's vegetarian curry + king trumpet mushroom ramen = most profitable. Sold 36 for $216.0
# 11-17-2018's vegetarian curry + king trumpet mushroom ramen = most expensive. A total cost of $252.0
#
# 11-18-2018's miso crab ramen = most profitable. Sold 12 for $72.0
# 11-18-2018's miso crab ramen = most expensive. A total cost of $72.0
#
# 11-19-2018's spicy miso ramen = most profitable. Sold 16 for $112.0
# 11-19-2018's spicy miso ramen = most expensive. A total cost of $80.0
#
# 11-20-2018's burnt garlic tonkotsu ramen = most profitable. Sold 22 for $176.0
# 11-20-2018's burnt garlic tonkotsu ramen = most expensive. A total cost of $132.0
#
# 11-21-2018's burnt garlic tonkotsu ramen = most profitable. Sold 12 for $96.0
# 11-21-2018's burnt garlic tonkotsu ramen = most expensive. A total cost of $72.0
#
# 11-22-2018's burnt garlic tonkotsu ramen = most profitable. Sold 24 for $192.0
# 11-22-2018's burnt garlic tonkotsu ramen = most expensive. A total cost of $144.0
#
# 11-23-2018's burnt garlic tonkotsu ramen = most profitable. Sold 10 for $80.0
# 11-23-2018's soft-shell miso crab ramen = most expensive. A total cost of $70.0
#
# 11-24-2018's nagomi shoyu = most profitable. Sold 30 for $180.0
# 11-24-2018's nagomi shoyu = most expensive. A total cost of $150.0
#
# 11-25-2018's burnt garlic tonkotsu ramen = most profitable. Sold 16 for $128.0
# 11-25-2018's burnt garlic tonkotsu ramen = most expensive. A total cost of $96.0
#
# 11-26-2018's tori paitan ramen = most profitable. Sold 8 for $56.0
# 11-26-2018's tori paitan ramen = most expensive. A total cost of $48.0
#
# 11-27-2018's miso crab ramen = most profitable. Sold 36 for $216.0
# 11-27-2018's miso crab ramen = most expensive. A total cost of $216.0
#
# 11-28-2018's tori paitan ramen = most profitable. Sold 24 for $168.0
# 11-28-2018's tori paitan ramen = most expensive. A total cost of $144.0
#
# 11-29-2018's tonkotsu ramen = most profitable. Sold 34 for $238.0
# 11-29-2018's tonkotsu ramen = most expensive. A total cost of $204.0
#
# 11-30-2018's nagomi shoyu = most profitable. Sold 24 for $144.0
# 11-30-2018's soft-shell miso crab ramen = most expensive. A total cost of $126.0
#
# 12-01-2018's tori paitan ramen = most profitable. Sold 38 for $266.0
# 12-01-2018's tori paitan ramen = most expensive. A total cost of $228.0
#
# 12-02-2018's tori paitan ramen = most profitable. Sold 10 for $70.0
# 12-02-2018's tori paitan ramen = most expensive. A total cost of $60.0
#
# 12-03-2018's vegetarian curry + king trumpet mushroom ramen = most profitable. Sold 16 for $96.0
# 12-03-2018's vegetarian curry + king trumpet mushroom ramen = most expensive. A total cost of $112.0
#
# 12-04-2018's tonkotsu ramen = most profitable. Sold 10 for $70.0
# 12-04-2018's tonkotsu ramen = most expensive. A total cost of $60.0
#
# 12-05-2018's tonkotsu ramen = most profitable. Sold 6 for $42.0
# 12-05-2018's vegetarian curry + king trumpet mushroom ramen = most expensive. A total cost of $42.0
#
# 12-06-2018's tonkotsu ramen = most profitable. Sold 14 for $98.0
# 12-06-2018's tonkotsu ramen = most expensive. A total cost of $84.0
#
# 12-07-2018's shio ramen = most profitable. Sold 14 for $84.0
# 12-07-2018's shio ramen = most expensive. A total cost of $70.0
#
# 12-08-2018's tonkotsu ramen = most profitable. Sold 24 for $168.0
# 12-08-2018's tonkotsu ramen = most expensive. A total cost of $144.0
#
# 12-09-2018's soft-shell miso crab ramen = most profitable. Sold 22 for $154.0
# 12-09-2018's soft-shell miso crab ramen = most expensive. A total cost of $154.0
#
# 12-10-2018's burnt garlic tonkotsu ramen = most profitable. Sold 20 for $160.0
# 12-10-2018's burnt garlic tonkotsu ramen = most expensive. A total cost of $120.0
#
# 12-11-2018's truffle butter ramen = most profitable. Sold 26 for $182.0
# 12-11-2018's truffle butter ramen = most expensive. A total cost of $182.0
#
# 12-12-2018's nagomi shoyu = most profitable. Sold 36 for $216.0
# 12-12-2018's nagomi shoyu = most expensive. A total cost of $180.0
#
# 12-13-2018's vegetarian curry + king trumpet mushroom ramen = most profitable. Sold 22 for $132.0
# 12-13-2018's vegetarian curry + king trumpet mushroom ramen = most expensive. A total cost of $154.0
#
# 12-14-2018's miso crab ramen = most profitable. Sold 8 for $48.0
# 12-14-2018's miso crab ramen = most expensive. A total cost of $48.0
#
# 12-15-2018's soft-shell miso crab ramen = most profitable. Sold 20 for $140.0
# 12-15-2018's soft-shell miso crab ramen = most expensive. A total cost of $140.0
#
# 12-16-2018's burnt garlic tonkotsu ramen = most profitable. Sold 34 for $272.0
# 12-16-2018's soft-shell miso crab ramen = most expensive. A total cost of $210.0
#
# 12-17-2018's tonkotsu ramen = most profitable. Sold 22 for $154.0
# 12-17-2018's vegetarian curry + king trumpet mushroom ramen = most expensive. A total cost of $168.0
#
# 12-18-2018's burnt garlic tonkotsu ramen = most profitable. Sold 44 for $352.0
# 12-18-2018's burnt garlic tonkotsu ramen = most expensive. A total cost of $264.0
#
# 12-19-2018's tonkotsu ramen = most profitable. Sold 12 for $84.0
# 12-19-2018's vegetarian curry + king trumpet mushroom ramen = most expensive. A total cost of $84.0
#
# 12-20-2018's nagomi shoyu = most profitable. Sold 20 for $120.0
# 12-20-2018's vegetarian curry + king trumpet mushroom ramen = most expensive. A total cost of $112.0
#
# 12-21-2018's miso crab ramen = most profitable. Sold 50 for $300.0
# 12-21-2018's miso crab ramen = most expensive. A total cost of $300.0
#
# 12-22-2018's soft-shell miso crab ramen = most profitable. Sold 22 for $154.0
# 12-22-2018's soft-shell miso crab ramen = most expensive. A total cost of $154.0
#
# 12-23-2018's miso crab ramen = most profitable. Sold 18 for $108.0
# 12-23-2018's miso crab ramen = most expensive. A total cost of $108.0
#
# 12-24-2018's vegetarian spicy miso = most profitable. Sold 30 for $210.0
# 12-24-2018's truffle butter ramen = most expensive. A total cost of $196.0
#
# 12-25-2018's burnt garlic tonkotsu ramen = most profitable. Sold 28 for $224.0
# 12-25-2018's vegetarian curry + king trumpet mushroom ramen = most expensive. A total cost of $224.0
#
# 12-26-2018's truffle butter ramen = most profitable. Sold 38 for $266.0
# 12-26-2018's truffle butter ramen = most expensive. A total cost of $266.0
#
# 12-27-2018's burnt garlic tonkotsu ramen = most profitable. Sold 24 for $192.0
# 12-27-2018's burnt garlic tonkotsu ramen = most expensive. A total cost of $144.0
#
# 12-28-2018's miso crab ramen = most profitable. Sold 32 for $192.0
# 12-28-2018's miso crab ramen = most expensive. A total cost of $192.0
#
# 12-29-2018's tori paitan ramen = most profitable. Sold 34 for $238.0
# 12-29-2018's vegetarian curry + king trumpet mushroom ramen = most expensive. A total cost of $224.0
#
# 12-30-2018's truffle butter ramen = most profitable. Sold 30 for $210.0
# 12-30-2018's truffle butter ramen = most expensive. A total cost of $210.0
#
# 12-31-2018's burnt garlic tonkotsu ramen = most profitable. Sold 34 for $272.0
# 12-31-2018's miso crab ramen = most expensive. A total cost of $228.0
